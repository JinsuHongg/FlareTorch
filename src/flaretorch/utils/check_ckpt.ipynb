# %%
import torch

# %%
base_path = "/anvil/projects/x-cis251356/check_point/FlareTorch/mcd/"
model = '2meqot08_resnet34_mcp_epoch=7-val_loss=1.2375.ckpt'
ckpt = torch.load(
    base_path + model, 
    map_location="cpu",
    weights_only=False
)

# %%
ckpt.keys()
# Out:
# dict_keys(['epoch', 'global_step', 'pytorch-lightning_version', 'state_dict', 'loops', 'callbacks', 'optimizer_states', 'lr_schedulers', 'hparams_name', 'hyper_parameters'])

# %%
ckpt["hyper_parameters"]
# Out:
# {'model_type': 'resnet34',
#  'module_dict': {'num_forwards': 100},
#  'base_model_dict': {'in_channels': 1, 'time_steps': 1, 'p_drop': 0.5},
#  'loss_type': 'mse',
#  'optimizer_dict': {'type': 'adamw', 'lr': 5e-05, 'weight_decay': 0.1},
#  'scheduler_dict': {'use': 'cosine_warmup', 'monitor': 'val_loss', 'cosine_warmup': {'total_steps': 1000, 'warmup_ratio': 0.1}, 'plateau': {'mode': 'min', 'factor': 0.1, 'patience': 10}}}

# %%
# q = ckpt["hyper_parameters"]["module_dict"]["quantiles"]
# print(f"quantiles: {int((q[2] - q[0])*100):.1f}")

# %%
ckpt["state_dict"].keys()#["base_model.regressor.weight"]
# Out:
# odict_keys(['base_model.resnet.0.weight', 'base_model.resnet.1.weight', 'base_model.resnet.1.bias', 'base_model.resnet.1.running_mean', 'base_model.resnet.1.running_var', 'base_model.resnet.1.num_batches_tracked', 'base_model.resnet.4.0.conv1.weight', 'base_model.resnet.4.0.bn1.weight', 'base_model.resnet.4.0.bn1.bias', 'base_model.resnet.4.0.bn1.running_mean', 'base_model.resnet.4.0.bn1.running_var', 'base_model.resnet.4.0.bn1.num_batches_tracked', 'base_model.resnet.4.0.conv2.weight', 'base_model.resnet.4.0.bn2.weight', 'base_model.resnet.4.0.bn2.bias', 'base_model.resnet.4.0.bn2.running_mean', 'base_model.resnet.4.0.bn2.running_var', 'base_model.resnet.4.0.bn2.num_batches_tracked', 'base_model.resnet.4.1.conv1.weight', 'base_model.resnet.4.1.bn1.weight', 'base_model.resnet.4.1.bn1.bias', 'base_model.resnet.4.1.bn1.running_mean', 'base_model.resnet.4.1.bn1.running_var', 'base_model.resnet.4.1.bn1.num_batches_tracked', 'base_model.resnet.4.1.conv2.weight', 'base_model.resnet.4.1.bn2
# ...
